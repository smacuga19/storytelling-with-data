# %% [markdown]
# # Programming basics — companion notebook
#
# **PSYC 81.09: Storytelling with Data**
# Jeremy R. Manning · Dartmouth College · Spring 2026
#
# This notebook accompanies the [Programming basics lecture](programming-basics.html). We'll work through **two** realistic problems — the kinds of things you'll actually do in your Part II data stories. The goal is to *write* code, not just read it.
#
# **How to use this notebook:**
# - Run each cell with `Shift + Enter`
# - Try modifying the examples — break them on purpose!
# - Use AI tools (chat.dartmouth.edu, Claude Code) when you get stuck
# - Read error messages carefully — they usually tell you exactly what's wrong

# %% [markdown]
# ---
#
# ## Problem 1: exploring a real dataset
#
# You have a list of songs, each a dict with `title`, `artist`, `genre`, and `plays`. **Your task:** find the three genres with the highest *average* plays per song.
#
# This looks like a simple question, but it's a complete analysis pipeline: **group**, **aggregate**, **sort**, **slice**. You'll do some version of this in every Part II project.

# %%
songs = [
    # Pop — lots of mega-hits and reliable streamers
    {'title': 'Blinding Lights',      'artist': 'The Weeknd',     'genre': 'pop',        'plays': 4_200_000_000, 'year': 2019},
    {'title': 'Save Your Tears',      'artist': 'The Weeknd',     'genre': 'pop',        'plays': 2_900_000_000, 'year': 2020},
    {'title': 'Starboy',              'artist': 'The Weeknd',     'genre': 'pop',        'plays': 3_400_000_000, 'year': 2016},
    {'title': 'Shape of You',         'artist': 'Ed Sheeran',     'genre': 'pop',        'plays': 3_800_000_000, 'year': 2017},
    {'title': 'Perfect',              'artist': 'Ed Sheeran',     'genre': 'pop',        'plays': 3_100_000_000, 'year': 2017},
    {'title': 'Thinking Out Loud',    'artist': 'Ed Sheeran',     'genre': 'pop',        'plays': 2_500_000_000, 'year': 2014},
    {'title': 'Someone Like You',     'artist': 'Adele',          'genre': 'pop',        'plays': 2_100_000_000, 'year': 2011},
    {'title': 'Hello',                'artist': 'Adele',          'genre': 'pop',        'plays': 3_300_000_000, 'year': 2015},
    {'title': 'Rolling in the Deep',  'artist': 'Adele',          'genre': 'pop',        'plays': 2_050_000_000, 'year': 2010},
    {'title': 'Bad Guy',              'artist': 'Billie Eilish',  'genre': 'pop',        'plays': 2_700_000_000, 'year': 2019},
    {'title': 'Anti-Hero',            'artist': 'Taylor Swift',   'genre': 'pop',        'plays': 1_950_000_000, 'year': 2022},
    {'title': 'Cruel Summer',         'artist': 'Taylor Swift',   'genre': 'pop',        'plays': 2_200_000_000, 'year': 2019},
    {'title': 'Shake It Off',         'artist': 'Taylor Swift',   'genre': 'pop',        'plays': 3_000_000_000, 'year': 2014},
    {'title': 'Flowers',              'artist': 'Miley Cyrus',    'genre': 'pop',        'plays': 2_400_000_000, 'year': 2023},

    # Rock — classic catalog with deep back-catalog plays
    {'title': 'Bohemian Rhapsody',    'artist': 'Queen',          'genre': 'rock',       'plays': 2_400_000_000, 'year': 1975},
    {'title': 'Dont Stop Me Now',     'artist': 'Queen',          'genre': 'rock',       'plays': 1_100_000_000, 'year': 1978},
    {'title': 'Under Pressure',       'artist': 'Queen',          'genre': 'rock',       'plays':   820_000_000, 'year': 1981},
    {'title': 'Sweet Child O Mine',   'artist': 'Guns N Roses',   'genre': 'rock',       'plays': 1_900_000_000, 'year': 1987},
    {'title': 'November Rain',        'artist': 'Guns N Roses',   'genre': 'rock',       'plays': 2_100_000_000, 'year': 1991},
    {'title': 'Hotel California',     'artist': 'Eagles',         'genre': 'rock',       'plays': 1_300_000_000, 'year': 1977},
    {'title': 'Stairway to Heaven',   'artist': 'Led Zeppelin',   'genre': 'rock',       'plays': 1_450_000_000, 'year': 1971},
    {'title': 'Smells Like Teen Spirit','artist': 'Nirvana',      'genre': 'rock',       'plays': 2_250_000_000, 'year': 1991},
    {'title': 'Come As You Are',      'artist': 'Nirvana',        'genre': 'rock',       'plays': 1_150_000_000, 'year': 1991},
    {'title': 'Wonderwall',           'artist': 'Oasis',          'genre': 'rock',       'plays': 2_300_000_000, 'year': 1995},
    {'title': 'Dont Look Back',       'artist': 'Oasis',          'genre': 'rock',       'plays': 1_080_000_000, 'year': 1995},

    # Hip-hop — streaming-era dominance
    {'title': 'Gods Plan',            'artist': 'Drake',          'genre': 'hip-hop',    'plays': 2_500_000_000, 'year': 2018},
    {'title': 'In My Feelings',       'artist': 'Drake',          'genre': 'hip-hop',    'plays': 2_100_000_000, 'year': 2018},
    {'title': 'One Dance',            'artist': 'Drake',          'genre': 'hip-hop',    'plays': 3_500_000_000, 'year': 2016},
    {'title': 'Hotline Bling',        'artist': 'Drake',          'genre': 'hip-hop',    'plays': 1_800_000_000, 'year': 2015},
    {'title': 'Lose Yourself',        'artist': 'Eminem',         'genre': 'hip-hop',    'plays': 1_600_000_000, 'year': 2002},
    {'title': 'Without Me',           'artist': 'Eminem',         'genre': 'hip-hop',    'plays': 1_300_000_000, 'year': 2002},
    {'title': 'Love the Way You Lie', 'artist': 'Eminem',         'genre': 'hip-hop',    'plays': 2_200_000_000, 'year': 2010},
    {'title': 'HUMBLE.',              'artist': 'Kendrick Lamar', 'genre': 'hip-hop',    'plays': 1_800_000_000, 'year': 2017},
    {'title': 'Alright',              'artist': 'Kendrick Lamar', 'genre': 'hip-hop',    'plays':   780_000_000, 'year': 2015},
    {'title': 'Money Trees',          'artist': 'Kendrick Lamar', 'genre': 'hip-hop',    'plays': 1_050_000_000, 'year': 2012},
    {'title': 'Old Town Road',        'artist': 'Lil Nas X',      'genre': 'hip-hop',    'plays': 2_800_000_000, 'year': 2019},
    {'title': 'Sicko Mode',           'artist': 'Travis Scott',   'genre': 'hip-hop',    'plays': 2_600_000_000, 'year': 2018},

    # Indie / alternative — smaller but devoted audiences
    {'title': 'Do I Wanna Know?',     'artist': 'Arctic Monkeys', 'genre': 'indie',      'plays': 1_750_000_000, 'year': 2013},
    {'title': 'R U Mine?',            'artist': 'Arctic Monkeys', 'genre': 'indie',      'plays':   880_000_000, 'year': 2012},
    {'title': 'Mr. Brightside',       'artist': 'The Killers',    'genre': 'indie',      'plays': 2_500_000_000, 'year': 2003},
    {'title': 'Somebody Told Me',     'artist': 'The Killers',    'genre': 'indie',      'plays':   620_000_000, 'year': 2004},
    {'title': 'Electric Feel',        'artist': 'MGMT',           'genre': 'indie',      'plays':   540_000_000, 'year': 2008},
    {'title': 'Kids',                 'artist': 'MGMT',           'genre': 'indie',      'plays':   810_000_000, 'year': 2008},

    # Electronic / EDM
    {'title': 'Levels',               'artist': 'Avicii',         'genre': 'electronic', 'plays': 1_100_000_000, 'year': 2011},
    {'title': 'Wake Me Up',           'artist': 'Avicii',         'genre': 'electronic', 'plays': 2_500_000_000, 'year': 2013},
    {'title': 'Hey Brother',          'artist': 'Avicii',         'genre': 'electronic', 'plays': 1_400_000_000, 'year': 2013},
    {'title': 'Titanium',             'artist': 'David Guetta',   'genre': 'electronic', 'plays': 2_050_000_000, 'year': 2011},
    {'title': 'Closer',               'artist': 'The Chainsmokers','genre': 'electronic','plays': 3_200_000_000, 'year': 2016},
    {'title': 'Dont You Worry Child', 'artist': 'Swedish House Mafia','genre': 'electronic','plays': 1_050_000_000, 'year': 2012},

    # Jazz — long tail, niche audience
    {'title': 'Take Five',            'artist': 'Dave Brubeck',   'genre': 'jazz',       'plays':   450_000_000, 'year': 1959},
    {'title': 'So What',              'artist': 'Miles Davis',    'genre': 'jazz',       'plays':   380_000_000, 'year': 1959},
    {'title': 'My Favorite Things',   'artist': 'John Coltrane',  'genre': 'jazz',       'plays':   210_000_000, 'year': 1961},
    {'title': 'A Love Supreme',       'artist': 'John Coltrane',  'genre': 'jazz',       'plays':   150_000_000, 'year': 1965},
    {'title': 'Feeling Good',         'artist': 'Nina Simone',    'genre': 'jazz',       'plays':   720_000_000, 'year': 1965},

    # Classical — surprisingly strong streaming for a few warhorses
    {'title': 'Clair de Lune',        'artist': 'Debussy',        'genre': 'classical',  'plays':   620_000_000, 'year': 1890},
    {'title': 'Moonlight Sonata',     'artist': 'Beethoven',      'genre': 'classical',  'plays':   710_000_000, 'year': 1801},
    {'title': 'Symphony No. 9',       'artist': 'Beethoven',      'genre': 'classical',  'plays':   340_000_000, 'year': 1824},
    {'title': 'Canon in D',           'artist': 'Pachelbel',      'genre': 'classical',  'plays':   520_000_000, 'year': 1680},
    {'title': 'Four Seasons: Spring', 'artist': 'Vivaldi',        'genre': 'classical',  'plays':   410_000_000, 'year': 1725},

    # Country — strong but less concentrated
    {'title': 'Cruise',               'artist': 'Florida Georgia Line','genre': 'country','plays': 950_000_000, 'year': 2012},
    {'title': 'Body Like a Back Road','artist': 'Sam Hunt',       'genre': 'country',    'plays':   780_000_000, 'year': 2017},
    {'title': 'Tennessee Whiskey',    'artist': 'Chris Stapleton','genre': 'country',    'plays':   850_000_000, 'year': 2015},
    {'title': 'Meant to Be',          'artist': 'Bebe Rexha',     'genre': 'country',    'plays':   680_000_000, 'year': 2017},
]

# Quick summary
genres = set(s['genre'] for s in songs)
artists = set(s['artist'] for s in songs)
print(f'{len(songs)} songs · {len(artists)} artists · {len(genres)} genres')
print(f'Genres: {sorted(genres)}')

# %% [markdown]
# ### Step 1: group plays by genre
#
# We need to collect all the play counts for each genre into a single place — a dictionary where the keys are genres and the values are lists of play counts.

# %%
plays_by_genre = {}
for song in songs:
    g = song['genre']
    plays_by_genre.setdefault(g, []).append(song['plays'])

# Look at what we built
for genre, plays in plays_by_genre.items():
    print(f'{genre}: {len(plays)} songs, total plays = {sum(plays):,}')

# %% [markdown]
# **`setdefault` explained:** `d.setdefault(key, default)` returns the value at `key` if it exists, otherwise inserts `default` and returns it. It's a concise way to build up a dict-of-lists without writing `if key not in d: d[key] = []` every time.

# %% [markdown]
# ### Step 2: compute the average per genre
#
# Now a dictionary comprehension turns our dict-of-lists into a dict-of-averages.

# %%
avg_by_genre = {
    g: sum(plays) / len(plays)
    for g, plays in plays_by_genre.items()
}

for genre, avg in avg_by_genre.items():
    print(f'{genre}: avg {avg:,.0f} plays per song')

# %% [markdown]
# ### Step 3: sort by average plays, descending
#
# The `key` argument of `sorted` lets us sort by any derived value. Using `-x[1]` (negate the value) gives us descending order.

# %%
ranked = sorted(avg_by_genre.items(), key=lambda item: -item[1])
for genre, avg in ranked:
    print(f'{genre}: {avg:,.0f}')

# %% [markdown]
# ### Step 4: take the top 3

# %%
top_three = ranked[:3]
print('Top 3 genres by average plays:')
for i, (genre, avg) in enumerate(top_three, start=1):
    print(f'  {i}. {genre} ({avg:,.0f} plays/song)')

# %% [markdown]
# ### Challenge: extend the analysis
#
# Try one or more of the following. Each asks you to reuse the same pipeline with a twist:
#
# 1. Find the top 3 genres by **median** plays instead of mean. Does the ranking change? Why?
# 2. Find the top **artist** (not genre) by total plays across all their songs.
# 3. Print a bar-chart-style output using `█` characters, where each bar's length is proportional to the average plays for that genre.
# 4. Add more songs to the dataset. Does your pipeline still work without modification? (It should!)

# %%
# Your turn:

# %% [markdown]
# ---
#
# ## Problem 2: find and fix the sneaky bug
#
# The function below is supposed to return a dict mapping each student to their average grade. It runs without errors — but the numbers are wrong. Can you find the bug?

# %%
def student_averages(grades):
    result = {}
    for student, scores in grades.items():
        total = 0
        for s in scores:
            total += s
        result[student] = total / len(grades)
    return result

grades = {
    'Ada':   [90, 85, 92],
    'Grace': [78, 88],
    'Alan':  [95, 91, 88, 84],
}

print(student_averages(grades))

# %% [markdown]
# **Trace it by hand first.** What should Grace's average be? (78 + 88) / 2 = **83**. What does the function return?
#
# **Debugging strategy:**
#
# 1. Verify by hand what the answer *should* be
# 2. Read the code one line at a time — what is each variable at each step?
# 3. Add `print` statements to show intermediate values
# 4. Ask AI: *"this function returns wrong numbers — walk through it step by step"*

# %% [markdown]
# ### The fix

# %%
def student_averages(grades):
    result = {}
    for student, scores in grades.items():
        total = 0
        for s in scores:
            total += s
        result[student] = total / len(scores)  # was len(grades) — wrong denominator
    return result

print(student_averages(grades))
# Expected: {'Ada': 89.0, 'Grace': 83.0, 'Alan': 89.5}

# %% [markdown]
# **Why this was sneaky:** Ada's average came out right *by coincidence* — she had 3 scores and there are 3 students, so `total / len(grades)` equaled `total / len(scores)`. The bug was invisible until you tested a student with a different number of scores.
#
# **Lesson:** always test with inputs that have *different shapes*. If every input has the same size, coincidences can hide bugs.

# %% [markdown]
# ### Challenge: write a more robust version
#
# Extend `student_averages` to handle edge cases:
#
# 1. A student with an **empty list** of scores — what should happen?
# 2. A student whose scores include a non-number (e.g., `'absent'`)
# 3. An **empty `grades` dict** — what should happen?
#
# There's more than one reasonable answer. What does the *caller* of this function need?

# %%
# Your turn:

# %% [markdown]
# ---
#
# ## Wrap-up
#
# You've practiced the two patterns you'll reuse constantly:
#
# 1. **Group → aggregate → sort → slice** — the core of every data analysis
# 2. **Verify with small examples** — the fastest way to catch subtle bugs
#
# Next up: **GitHub** — how to version, share, and collaborate on your code (and submit Assignment 3).
